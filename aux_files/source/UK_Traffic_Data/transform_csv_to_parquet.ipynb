# %% [markdown]
# ## As the original file: dft_traffic_counts_raw_counts.csv was too heavy, we transformed it into a parquet file to save storage size

# %% [markdown]
# ### Anyway, you can find the original file at: https://roadtraffic.dft.gov.uk/downloads

# %%
import pandas as pd;
import os;

# %%
# We use this function to check the size of 
# any file from his path
# Arguments:
# path (str): File path
# Return:
# None
def get_file_stats (path):
    file_stats = os.stat(path)
    print(f'File Size in MegaBytes is {file_stats.st_size / (1024 * 1024)}')

# %%
file_path = r'aux_files\source\UK_Traffic_Data\dft_traffic_counts_raw_counts.csv'
get_file_stats (file_path)
df = pd.read_csv(file_path, header=0, sep=',', dtype=str).\
    replace('nan', pd.NA) ## Avoid having "nan" text instead of null values, if they exist. 
df
# Out:
# File Size in MegaBytes is 1208.8800992965698
#         Count_point_id Direction_of_travel  Year           Count_date hour  \
# 0                  749                   E  2014  2014-06-25 00:00:00    7
# 1                  749                   E  2014  2014-06-25 00:00:00    8
# 2                  749                   E  2014  2014-06-25 00:00:00    9
# 3                  749                   E  2014  2014-06-25 00:00:00   10
# 4                  749                   E  2014  2014-06-25 00:00:00   11
# ...                ...                 ...   ...                  ...  ...
# 4815499         811618                   E  2020  2020-06-05 00:00:00   14
# 4815500         811618                   E  2020  2020-06-05 00:00:00   15
# 4815501         811618                   E  2020  2020-06-05 00:00:00   16
# 4815502         811618                   E  2020  2020-06-05 00:00:00   17
# 4815503         811618                   E  2020  2020-06-05 00:00:00   18
#
#         Region_id Region_name Region_ons_code Local_authority_id  \
# 0               3    Scotland       S92000003                 39
# 1               3    Scotland       S92000003                 39
# 2               3    Scotland       S92000003                 39
# 3               3    Scotland       S92000003                 39
# 4               3    Scotland       S92000003                 39
# ...           ...         ...             ...                ...
# 4815499         3    Scotland       S92000003                 31
# 4815500         3    Scotland       S92000003                 31
# 4815501         3    Scotland       S92000003                 31
# 4815502         3    Scotland       S92000003                 31
# 4815503         3    Scotland       S92000003                 31
#
#         Local_authority_name  ... Buses_and_coaches LGVs HGVs_2_rigid_axle  \
# 0              East Ayrshire  ...                 5   31                15
# 1              East Ayrshire  ...                 7  103                29
# 2              East Ayrshire  ...                14   88                21
# 3              East Ayrshire  ...                 8   90                31
# 4              East Ayrshire  ...                18   75                38
# ...                      ...  ...               ...  ...               ...
# 4815499      Perth & Kinross  ...                 1    8                 0
# 4815500      Perth & Kinross  ...                 0   14                 0
# 4815501      Perth & Kinross  ...                 0   15                 2
# 4815502      Perth & Kinross  ...                 1    8                 0
# 4815503      Perth & Kinross  ...                 1    8                 0
#
#         HGVs_3_rigid_axle HGVs_4_or_more_rigid_axle  \
# 0                       4                         4
# 1                       3                         2
# 2                       3                         5
# 3                       6                        10
# 4                       2                         2
# ...                   ...                       ...
# 4815499                 0                         0
# 4815500                 0                         0
# 4815501                 0                         0
# 4815502                 0                         0
# 4815503                 0                         0
#
#         HGVs_3_or_4_articulated_axle HGVs_5_articulated_axle  \
# 0                                  4                      13
# 1                                  7                      18
# 2                                  9                      17
# 3                                  7                      18
# 4                                  3                      16
# ...                              ...                     ...
# 4815499                            0                       0
# 4815500                            0                       0
# 4815501                            0                       0
# 4815502                            0                       0
# 4815503                            0                       0
#
#         HGVs_6_articulated_axle All_HGVs All_motor_vehicles
# 0                            12       52                935
# 1                            20       79               1102
# 2                            19       74                773
# 3                            17       89                778
# 4                            24       85                875
# ...                         ...      ...                ...
# 4815499                       0        0                 57
# 4815500                       0        0                 74
# 4815501                       1        3                 69
# 4815502                       0        0                 73
# 4815503                       1        1                 49
#
# [4815504 rows x 35 columns]

# %%
df.to_parquet(r'aux_files\source\UK_Traffic_Data\dft_traffic_counts_raw_counts.parquet', compression='snappy')

# %% [markdown]
# ### Checking if everything is fine

# %%
file_path = r'aux_files\source\UK_Traffic_Data\dft_traffic_counts_raw_counts.parquet'
get_file_stats (file_path)
df = pd.read_parquet(file_path)
df
# Out:
# File Size in MegaBytes is 62.42549800872803
#         Count_point_id Direction_of_travel  Year           Count_date hour  \
# 0                  749                   E  2014  2014-06-25 00:00:00    7
# 1                  749                   E  2014  2014-06-25 00:00:00    8
# 2                  749                   E  2014  2014-06-25 00:00:00    9
# 3                  749                   E  2014  2014-06-25 00:00:00   10
# 4                  749                   E  2014  2014-06-25 00:00:00   11
# ...                ...                 ...   ...                  ...  ...
# 4815499         811618                   E  2020  2020-06-05 00:00:00   14
# 4815500         811618                   E  2020  2020-06-05 00:00:00   15
# 4815501         811618                   E  2020  2020-06-05 00:00:00   16
# 4815502         811618                   E  2020  2020-06-05 00:00:00   17
# 4815503         811618                   E  2020  2020-06-05 00:00:00   18
#
#         Region_id Region_name Region_ons_code Local_authority_id  \
# 0               3    Scotland       S92000003                 39
# 1               3    Scotland       S92000003                 39
# 2               3    Scotland       S92000003                 39
# 3               3    Scotland       S92000003                 39
# 4               3    Scotland       S92000003                 39
# ...           ...         ...             ...                ...
# 4815499         3    Scotland       S92000003                 31
# 4815500         3    Scotland       S92000003                 31
# 4815501         3    Scotland       S92000003                 31
# 4815502         3    Scotland       S92000003                 31
# 4815503         3    Scotland       S92000003                 31
#
#         Local_authority_name  ... Buses_and_coaches LGVs HGVs_2_rigid_axle  \
# 0              East Ayrshire  ...                 5   31                15
# 1              East Ayrshire  ...                 7  103                29
# 2              East Ayrshire  ...                14   88                21
# 3              East Ayrshire  ...                 8   90                31
# 4              East Ayrshire  ...                18   75                38
# ...                      ...  ...               ...  ...               ...
# 4815499      Perth & Kinross  ...                 1    8                 0
# 4815500      Perth & Kinross  ...                 0   14                 0
# 4815501      Perth & Kinross  ...                 0   15                 2
# 4815502      Perth & Kinross  ...                 1    8                 0
# 4815503      Perth & Kinross  ...                 1    8                 0
#
#         HGVs_3_rigid_axle HGVs_4_or_more_rigid_axle  \
# 0                       4                         4
# 1                       3                         2
# 2                       3                         5
# 3                       6                        10
# 4                       2                         2
# ...                   ...                       ...
# 4815499                 0                         0
# 4815500                 0                         0
# 4815501                 0                         0
# 4815502                 0                         0
# 4815503                 0                         0
#
#         HGVs_3_or_4_articulated_axle HGVs_5_articulated_axle  \
# 0                                  4                      13
# 1                                  7                      18
# 2                                  9                      17
# 3                                  7                      18
# 4                                  3                      16
# ...                              ...                     ...
# 4815499                            0                       0
# 4815500                            0                       0
# 4815501                            0                       0
# 4815502                            0                       0
# 4815503                            0                       0
#
#         HGVs_6_articulated_axle All_HGVs All_motor_vehicles
# 0                            12       52                935
# 1                            20       79               1102
# 2                            19       74                773
# 3                            17       89                778
# 4                            24       85                875
# ...                         ...      ...                ...
# 4815499                       0        0                 57
# 4815500                       0        0                 74
# 4815501                       1        3                 69
# 4815502                       0        0                 73
# 4815503                       1        1                 49
#
# [4815504 rows x 35 columns]
