# %% [markdown]
# ### Importing necessary libraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import math
import time
from datetime import datetime
from sqlalchemy import create_engine, text

# %% [markdown]
# <div align = 'center'>
# <h1>Games Data Scrap</h>
# </div>

# %% [markdown]
# ### Defining necessary variables

# %%
rows_by_page = 200 ## You can choose between 50, 100 or 200

## MODE FULL | DELTA, It will determine if it's a full or an incremental load of the data.
try:
    MODE = PMODE ## If It comes from another notebook
except:
    MODE = "DELTA"
## Full load: We will scrap every existing record on webpage
## Incremental load: We will scrap the latest 1000 updated records. 
print(f"Mode: {MODE}")

# URL of vgchartz table, on its first page. Everything ordered by "Last Update Date"
# To get the latest data.
url = f"https://www.vgchartz.com/games/games.php?page=1&results={str(rows_by_page)}&order=LastUpdate&ownership=Both&direction=DESC&showtotalsales=1&shownasales=1&showpalsales=1&showjapansales=1&showothersales=1&showpublisher=1&showdeveloper=1&showreleasedate=1&showlastupdate=1&showvgchartzscore=1&showcriticscore=1&showuserscore=1&showshipped=1"

# Creating an empty list to save each webpage table
data = []

## To identify from which page we need to retry
retry_page = 0
# Out:
# Mode: FULL

# %% [markdown]
# ### Necessary Functions

# %%
def text_to_date(text):
    if pd.isnull(text):
        return text
    else:
        # Discard "th" from the text
        non_suffix_date = text.replace('th', '').replace('st', '').replace('nd', '').replace('rd', '')
        date = datetime.strptime(non_suffix_date, '%d %b %y').date()
        return date


def web_scrapping (number_of_pages, rows_by_page, initial_page):
    try: ##We won't validate response code, because even when it fails, Its status code == 200. Try/Except will work better
        for x in range(initial_page, number_of_pages+1): ## If it fails at any page, we can easily replace the "1" by the last succesfully scrapped page
            time.sleep(5) ## To avoid timeout error
            url = f"https://www.vgchartz.com/games/games.php?page={str(x)}&results={str(rows_by_page)}&order=LastUpdate&ownership=Both&direction=DESC&showtotalsales=1&shownasales=1&showpalsales=1&showjapansales=1&showothersales=1&showpublisher=1&showdeveloper=1&showreleasedate=1&showlastupdate=1&showvgchartzscore=1&showcriticscore=1&showuserscore=1&showshipped=1"

            response = requests.get(url)

            soup = BeautifulSoup(response.text, 'html.parser')

            counter = 0 ## We need to add a column on the third row (because of webpage's table format)
            table = soup.find('div', {'id': 'generalBody'}).find('table')
            every_row = table.find_all('tr')

            if len(every_row) <= 3:
                print(f"No results returned on page {x} :(")
                raise ValueError(f"No results returned on page {x} :(")

            # Iterating over every row
            for row in every_row:

                # Getting cells from every row
                cells = row.find_all(['th', 'td'])

                row_data = [] ## A list with every table's row
                for cell in cells:
                    img = cell.find('img')

                    if img:
                        img = img.replace_with(img.text)
                        img = str(img).split('"')[1] #We need "alt" attr value for getting the "Console" value
                        row_data.append(str(img))

                    else: ##It's not an image, so we just strip the data string value
                        row_data.append(cell.text.strip())

                if (counter == 2):
                    row_data.insert(2, 'GameName')

                global data

                data.append(row_data) ## Saving current row into "every row" list

                counter = counter + 1 ## Number of rows iterated

            print(f"Page {str(x)} Succesfully Scrapped!")
    except Exception as e:
        global retry_page
        if retry_page != 0:
            raise ValueError(f'Page {str(x)} Request Failed. With the following message: {str(e)}')
        else:
            retry_page = x
            print(f"Failed on page {str(x)}. Retrying....")

# %% [markdown]
# ### Web Scrapping

# %%
# Making a request on first page, to get the number of Results.
response = requests.get(url) 

# Code 200 means everything is ok!
if response.status_code == 200:
    # parsing HTML content
    soup = BeautifulSoup(response.text, 'html.parser')

    # Finding table inside webpage
    table = soup.find('div', {'id': 'generalBody'}).find('table')
    
    if MODE == "FULL":
        ## Getting total number of games, to realize how many times we should iterate over the url page number
        first_row = table.find('tr')
        results = first_row.find('th')
        results = str(results.text).replace('Results: (', '').replace(')', '').replace(',', '')
        results = int(results)

        number_of_pages = math.ceil(results/rows_by_page)
    else: ## If we making an incremental refresh, we will iterate over the first 1000 latest updated videogames.
        results = 1000
        number_of_pages = 5
    print("Number of videogames: ", results, " - ", "Number of Pages: ", number_of_pages)

    web_scrapping (number_of_pages, rows_by_page, 1)
    ## If It fails, we will retry the web scrapping from that page
    if retry_page != 0:
        time.sleep(5)
        web_scrapping (number_of_pages, rows_by_page, retry_page)

    videogames_sales_df = pd.DataFrame(data)

else:
    raise ValueError(f'Request on first page Failed. Status Code: {response.status_code}')
# Out:
# Number of videogames:  63916  -  Number of Pages:  320
# Page 1 Succesfully Scrapped!
# Page 2 Succesfully Scrapped!
# Page 3 Succesfully Scrapped!
# Page 4 Succesfully Scrapped!
# Page 5 Succesfully Scrapped!
# Page 6 Succesfully Scrapped!
# Page 7 Succesfully Scrapped!
# Page 8 Succesfully Scrapped!
# Page 9 Succesfully Scrapped!
# Page 10 Succesfully Scrapped!
# Page 11 Succesfully Scrapped!
# Page 12 Succesfully Scrapped!
# Page 13 Succesfully Scrapped!
# Page 14 Succesfully Scrapped!
# Page 15 Succesfully Scrapped!
# Page 16 Succesfully Scrapped!
# Page 17 Succesfully Scrapped!
# Page 18 Succesfully Scrapped!
# Page 19 Succesfully Scrapped!
# Page 20 Succesfully Scrapped!
# Page 21 Succesfully Scrapped!
# Page 22 Succesfully Scrapped!
# Page 23 Succesfully Scrapped!
# Page 24 Succesfully Scrapped!
# Page 25 Succesfully Scrapped!
# Page 26 Succesfully Scrapped!
# Page 27 Succesfully Scrapped!
# Page 28 Succesfully Scrapped!
# Page 29 Succesfully Scrapped!
# Page 30 Succesfully Scrapped!
# Page 31 Succesfully Scrapped!
# Page 32 Succesfully Scrapped!
# Page 33 Succesfully Scrapped!
# Page 34 Succesfully Scrapped!
# Page 35 Succesfully Scrapped!
# Page 36 Succesfully Scrapped!
# Page 37 Succesfully Scrapped!
# Page 38 Succesfully Scrapped!
# Page 39 Succesfully Scrapped!
# Page 40 Succesfully Scrapped!
# Page 41 Succesfully Scrapped!
# Page 42 Succesfully Scrapped!
# Page 43 Succesfully Scrapped!
# Page 44 Succesfully Scrapped!
# Page 45 Succesfully Scrapped!
# Page 46 Succesfully Scrapped!
# Page 47 Succesfully Scrapped!
# Page 48 Succesfully Scrapped!
# Page 49 Succesfully Scrapped!
# Page 50 Succesfully Scrapped!
# Page 51 Succesfully Scrapped!
# Page 52 Succesfully Scrapped!
# Page 53 Succesfully Scrapped!
# Page 54 Succesfully Scrapped!
# Page 55 Succesfully Scrapped!
# Page 56 Succesfully Scrapped!
# Page 57 Succesfully Scrapped!
# Page 58 Succesfully Scrapped!
# Page 59 Succesfully Scrapped!
# Page 60 Succesfully Scrapped!
# Page 61 Succesfully Scrapped!
# Page 62 Succesfully Scrapped!
# Page 63 Succesfully Scrapped!
# Page 64 Succesfully Scrapped!
# Page 65 Succesfully Scrapped!
# Page 66 Succesfully Scrapped!
# Page 67 Succesfully Scrapped!
# Page 68 Succesfully Scrapped!
# Page 69 Succesfully Scrapped!
# Page 70 Succesfully Scrapped!
# Page 71 Succesfully Scrapped!
# Page 72 Succesfully Scrapped!
# Page 73 Succesfully Scrapped!
# Page 74 Succesfully Scrapped!
# Page 75 Succesfully Scrapped!
# Page 76 Succesfully Scrapped!
# Page 77 Succesfully Scrapped!
# Page 78 Succesfully Scrapped!
# Page 79 Succesfully Scrapped!
# Page 80 Succesfully Scrapped!
# Page 81 Succesfully Scrapped!
# Page 82 Succesfully Scrapped!
# Page 83 Succesfully Scrapped!
# Page 84 Succesfully Scrapped!
# Page 85 Succesfully Scrapped!
# Page 86 Succesfully Scrapped!
# Page 87 Succesfully Scrapped!
# Page 88 Succesfully Scrapped!
# Page 89 Succesfully Scrapped!
# Page 90 Succesfully Scrapped!
# Page 91 Succesfully Scrapped!
# Page 92 Succesfully Scrapped!
# Page 93 Succesfully Scrapped!
# Page 94 Succesfully Scrapped!
# Page 95 Succesfully Scrapped!
# Page 96 Succesfully Scrapped!
# Page 97 Succesfully Scrapped!
# Page 98 Succesfully Scrapped!
# Page 99 Succesfully Scrapped!
# Page 100 Succesfully Scrapped!
# Page 101 Succesfully Scrapped!
# Page 102 Succesfully Scrapped!
# Page 103 Succesfully Scrapped!
# Page 104 Succesfully Scrapped!
# Page 105 Succesfully Scrapped!
# Page 106 Succesfully Scrapped!
# Page 107 Succesfully Scrapped!
# Page 108 Succesfully Scrapped!
# Page 109 Succesfully Scrapped!
# Page 110 Succesfully Scrapped!
# Page 111 Succesfully Scrapped!
# Page 112 Succesfully Scrapped!
# Page 113 Succesfully Scrapped!
# Page 114 Succesfully Scrapped!
# Page 115 Succesfully Scrapped!
# Page 116 Succesfully Scrapped!
# Page 117 Succesfully Scrapped!
# Page 118 Succesfully Scrapped!
# Page 119 Succesfully Scrapped!
# Page 120 Succesfully Scrapped!
# Page 121 Succesfully Scrapped!
# Page 122 Succesfully Scrapped!
# Page 123 Succesfully Scrapped!
# Page 124 Succesfully Scrapped!
# Page 125 Succesfully Scrapped!
# Page 126 Succesfully Scrapped!
# Page 127 Succesfully Scrapped!
# Page 128 Succesfully Scrapped!
# Page 129 Succesfully Scrapped!
# Page 130 Succesfully Scrapped!
# Page 131 Succesfully Scrapped!
# Page 132 Succesfully Scrapped!
# Page 133 Succesfully Scrapped!
# Page 134 Succesfully Scrapped!
# Page 135 Succesfully Scrapped!
# Page 136 Succesfully Scrapped!
# Page 137 Succesfully Scrapped!
# Page 138 Succesfully Scrapped!
# Page 139 Succesfully Scrapped!
# Page 140 Succesfully Scrapped!
# Page 141 Succesfully Scrapped!
# Page 142 Succesfully Scrapped!
# Page 143 Succesfully Scrapped!
# Page 144 Succesfully Scrapped!
# Page 145 Succesfully Scrapped!
# Page 146 Succesfully Scrapped!
# Page 147 Succesfully Scrapped!
# Page 148 Succesfully Scrapped!
# Page 149 Succesfully Scrapped!
# Page 150 Succesfully Scrapped!
# Page 151 Succesfully Scrapped!
# Page 152 Succesfully Scrapped!
# Page 153 Succesfully Scrapped!
# Page 154 Succesfully Scrapped!
# Page 155 Succesfully Scrapped!
# Page 156 Succesfully Scrapped!
# Page 157 Succesfully Scrapped!
# Page 158 Succesfully Scrapped!
# Page 159 Succesfully Scrapped!
# Page 160 Succesfully Scrapped!
# Page 161 Succesfully Scrapped!
# Page 162 Succesfully Scrapped!
# Page 163 Succesfully Scrapped!
# Page 164 Succesfully Scrapped!
# Page 165 Succesfully Scrapped!
# Page 166 Succesfully Scrapped!
# Page 167 Succesfully Scrapped!
# Page 168 Succesfully Scrapped!
# Page 169 Succesfully Scrapped!
# Page 170 Succesfully Scrapped!
# Page 171 Succesfully Scrapped!
# Page 172 Succesfully Scrapped!
# Page 173 Succesfully Scrapped!
# Page 174 Succesfully Scrapped!
# Page 175 Succesfully Scrapped!
# Page 176 Succesfully Scrapped!
# Page 177 Succesfully Scrapped!
# Page 178 Succesfully Scrapped!
# Page 179 Succesfully Scrapped!
# Page 180 Succesfully Scrapped!
# Page 181 Succesfully Scrapped!
# Page 182 Succesfully Scrapped!
# Page 183 Succesfully Scrapped!
# Page 184 Succesfully Scrapped!
# Page 185 Succesfully Scrapped!
# Page 186 Succesfully Scrapped!
# Page 187 Succesfully Scrapped!
# Page 188 Succesfully Scrapped!
# Page 189 Succesfully Scrapped!
# Page 190 Succesfully Scrapped!
# Page 191 Succesfully Scrapped!
# Page 192 Succesfully Scrapped!
# Page 193 Succesfully Scrapped!
# Page 194 Succesfully Scrapped!
# Page 195 Succesfully Scrapped!
# Page 196 Succesfully Scrapped!
# Page 197 Succesfully Scrapped!
# Page 198 Succesfully Scrapped!
# Page 199 Succesfully Scrapped!
# Page 200 Succesfully Scrapped!
# Page 201 Succesfully Scrapped!
# Page 202 Succesfully Scrapped!
# Page 203 Succesfully Scrapped!
# Page 204 Succesfully Scrapped!
# Page 205 Succesfully Scrapped!
# Page 206 Succesfully Scrapped!
# Page 207 Succesfully Scrapped!
# Page 208 Succesfully Scrapped!
# Page 209 Succesfully Scrapped!
# Page 210 Succesfully Scrapped!
# Page 211 Succesfully Scrapped!
# Page 212 Succesfully Scrapped!
# Page 213 Succesfully Scrapped!
# Page 214 Succesfully Scrapped!
# Page 215 Succesfully Scrapped!
# Page 216 Succesfully Scrapped!
# Page 217 Succesfully Scrapped!
# Page 218 Succesfully Scrapped!
# Page 219 Succesfully Scrapped!
# Page 220 Succesfully Scrapped!
# Page 221 Succesfully Scrapped!
# Page 222 Succesfully Scrapped!
# Page 223 Succesfully Scrapped!
# Page 224 Succesfully Scrapped!
# Page 225 Succesfully Scrapped!
# Page 226 Succesfully Scrapped!
# Page 227 Succesfully Scrapped!
# Failed on page 228. Retrying....
# Page 228 Succesfully Scrapped!
# Page 229 Succesfully Scrapped!
# Page 230 Succesfully Scrapped!
# Page 231 Succesfully Scrapped!
# Page 232 Succesfully Scrapped!
# Page 233 Succesfully Scrapped!
# Page 234 Succesfully Scrapped!
# Page 235 Succesfully Scrapped!
# Page 236 Succesfully Scrapped!
# Page 237 Succesfully Scrapped!
# Page 238 Succesfully Scrapped!
# Page 239 Succesfully Scrapped!
# Page 240 Succesfully Scrapped!
# Page 241 Succesfully Scrapped!
# Page 242 Succesfully Scrapped!
# Page 243 Succesfully Scrapped!
# Page 244 Succesfully Scrapped!
# Page 245 Succesfully Scrapped!
# Page 246 Succesfully Scrapped!
# Page 247 Succesfully Scrapped!
# Page 248 Succesfully Scrapped!
# Page 249 Succesfully Scrapped!
# Page 250 Succesfully Scrapped!
# Page 251 Succesfully Scrapped!
# Page 252 Succesfully Scrapped!
# Page 253 Succesfully Scrapped!
# Page 254 Succesfully Scrapped!
# Page 255 Succesfully Scrapped!
# Page 256 Succesfully Scrapped!
# Page 257 Succesfully Scrapped!
# Page 258 Succesfully Scrapped!
# Page 259 Succesfully Scrapped!
# Page 260 Succesfully Scrapped!
# Page 261 Succesfully Scrapped!
# Page 262 Succesfully Scrapped!
# Page 263 Succesfully Scrapped!
# Page 264 Succesfully Scrapped!
# Page 265 Succesfully Scrapped!
# Page 266 Succesfully Scrapped!
# Page 267 Succesfully Scrapped!
# Page 268 Succesfully Scrapped!
# Page 269 Succesfully Scrapped!
# Page 270 Succesfully Scrapped!
# Page 271 Succesfully Scrapped!
# Page 272 Succesfully Scrapped!
# Page 273 Succesfully Scrapped!
# Page 274 Succesfully Scrapped!
# Page 275 Succesfully Scrapped!
# Page 276 Succesfully Scrapped!
# Page 277 Succesfully Scrapped!
# Page 278 Succesfully Scrapped!
# Page 279 Succesfully Scrapped!
# Page 280 Succesfully Scrapped!
# Page 281 Succesfully Scrapped!
# Page 282 Succesfully Scrapped!
# Page 283 Succesfully Scrapped!
# Page 284 Succesfully Scrapped!
# Page 285 Succesfully Scrapped!
# Page 286 Succesfully Scrapped!
# Page 287 Succesfully Scrapped!
# Page 288 Succesfully Scrapped!
# Page 289 Succesfully Scrapped!
# Page 290 Succesfully Scrapped!
# Page 291 Succesfully Scrapped!
# Page 292 Succesfully Scrapped!
# Page 293 Succesfully Scrapped!
# Page 294 Succesfully Scrapped!
# Page 295 Succesfully Scrapped!
# Page 296 Succesfully Scrapped!
# Page 297 Succesfully Scrapped!
# Page 298 Succesfully Scrapped!
# Page 299 Succesfully Scrapped!
# Page 300 Succesfully Scrapped!
# Page 301 Succesfully Scrapped!
# Page 302 Succesfully Scrapped!
# Page 303 Succesfully Scrapped!
# Page 304 Succesfully Scrapped!
# Page 305 Succesfully Scrapped!
# Page 306 Succesfully Scrapped!
# Page 307 Succesfully Scrapped!
# Page 308 Succesfully Scrapped!
# Page 309 Succesfully Scrapped!
# Page 310 Succesfully Scrapped!
# Page 311 Succesfully Scrapped!
# Page 312 Succesfully Scrapped!
# Page 313 Succesfully Scrapped!
# Page 314 Succesfully Scrapped!
# Page 315 Succesfully Scrapped!
# Page 316 Succesfully Scrapped!
# Page 317 Succesfully Scrapped!
# Page 318 Succesfully Scrapped!
# Page 319 Succesfully Scrapped!
# Page 320 Succesfully Scrapped!

# %%
videogames_sales_df
# Out:
#                                                       0   \
# 0                                      Results: (63,916)
# 1      A    B    C    D    E    F    G    H    I    J...
# 2                                                    Pos
# 3                                                      1
# 4                                                      2
# ...                                                  ...
# 64871                                              63912
# 64872                                              63913
# 64873                                              63914
# 64874                                              63915
# 64875                                              63916
#
#                              1   \
# 0      <<  1  2  3  4  5  6  >>
# 1                          None
# 2                          Game
# 3                Boxart Missing
# 4                Boxart Missing
# ...                         ...
# 64871            Boxart Missing
# 64872            Boxart Missing
# 64873            Boxart Missing
# 64874            Boxart Missing
# 64875            Boxart Missing
#
#                                                       2        3   \
# 0                                                   None     None
# 1                                                   None     None
# 2                                               GameName  Console
# 3      Star Wars: The Force Unleashed - Ultimate Sith...      PS3
# 4      Star Wars: The Force Unleashed - Ultimate Sith...     X360
# ...                                                  ...      ...
# 64871                                        [Prototype]     X360
# 64872                     [Prototype]    Read the review       PC
# 64873                                        [Prototype]      PSN
# 64874                                         _summer ##      PS2
# 64875                       ¡Shin Chan Flipa en colores!       DS
#
#                 4                      5               6             7   \
# 0             None                   None            None          None
# 1             None                   None            None          None
# 2        Publisher              Developer  VGChartz Score  Critic Score
# 3          Unknown              LucasArts             N/A           N/A
# 4          Unknown              LucasArts             N/A           N/A
# ...            ...                    ...             ...           ...
# 64871   Activision  Radical Entertainment             N/A           7.9
# 64872   Activision  Radical Entertainment             8.1           7.9
# 64873   Activision  Radical Entertainment             N/A           7.8
# 64874  GN Software            GN Software             N/A           N/A
# 64875    505 Games           Inti Creates             N/A           N/A
#
#                8              9            10        11         12  \
# 0            None           None         None      None       None
# 1            None           None         None      None       None
# 2      User Score  Total Shipped  Total Sales  NA Sales  PAL Sales
# 3             N/A            N/A          N/A       N/A        N/A
# 4             N/A            N/A          N/A       N/A        N/A
# ...           ...            ...          ...       ...        ...
# 64871         N/A            N/A        1.31m     0.84m      0.35m
# 64872         N/A            N/A          N/A       N/A        N/A
# 64873         N/A            N/A          N/A       N/A        N/A
# 64874         N/A            N/A          N/A       N/A        N/A
# 64875         N/A            N/A        0.14m       N/A        N/A
#
#                 13           14            15           16
# 0             None         None          None         None
# 1             None         None          None         None
# 2      Japan Sales  Other Sales  Release Date  Last Update
# 3              N/A          N/A           N/A  06th Jan 24
# 4              N/A          N/A           N/A  06th Jan 24
# ...            ...          ...           ...          ...
# 64871          N/A        0.12m   09th Jun 09          N/A
# 64872          N/A          N/A   09th Jun 09          N/A
# 64873          N/A          N/A   14th Dec 10          N/A
# 64874          N/A          N/A   24th Aug 06          N/A
# 64875        0.14m          N/A   16th Nov 07          N/A
#
# [64876 rows x 17 columns]

# %%
videogames_sales_df.head(7)
# Out:
#                                                   0   \
# 0                                  Results: (63,916)
# 1  A    B    C    D    E    F    G    H    I    J...
# 2                                                Pos
# 3                                                  1
# 4                                                  2
# 5                                                  3
# 6                                                  4
#
#                          1   \
# 0  <<  1  2  3  4  5  6  >>
# 1                      None
# 2                      Game
# 3            Boxart Missing
# 4            Boxart Missing
# 5            Boxart Missing
# 6            Boxart Missing
#
#                                                   2        3          4   \
# 0                                               None     None       None
# 1                                               None     None       None
# 2                                           GameName  Console  Publisher
# 3  Star Wars: The Force Unleashed - Ultimate Sith...      PS3    Unknown
# 4  Star Wars: The Force Unleashed - Ultimate Sith...     X360    Unknown
# 5  Star Wars: The Force Unleashed - Ultimate Sith...       PC    Unknown
# 6                                             Contra       PC    Unknown
#
#           5               6             7           8              9   \
# 0       None            None          None        None           None
# 1       None            None          None        None           None
# 2  Developer  VGChartz Score  Critic Score  User Score  Total Shipped
# 3  LucasArts             N/A           N/A         N/A            N/A
# 4  LucasArts             N/A           N/A         N/A            N/A
# 5  LucasArts             N/A           N/A         N/A            N/A
# 6     Konami             N/A           N/A         N/A            N/A
#
#             10        11         12           13           14            15  \
# 0         None      None       None         None         None          None
# 1         None      None       None         None         None          None
# 2  Total Sales  NA Sales  PAL Sales  Japan Sales  Other Sales  Release Date
# 3          N/A       N/A        N/A          N/A          N/A           N/A
# 4          N/A       N/A        N/A          N/A          N/A           N/A
# 5          N/A       N/A        N/A          N/A          N/A           N/A
# 6          N/A       N/A        N/A          N/A          N/A           N/A
#
#             16
# 0         None
# 1         None
# 2  Last Update
# 3  06th Jan 24
# 4  06th Jan 24
# 5  06th Jan 24
# 6  05th Jan 24

# %% [markdown]
# ### Format Adaptations

# %%
videogames_sales_df = videogames_sales_df[( videogames_sales_df[videogames_sales_df.columns[0]].str.isnumeric() ) | ( videogames_sales_df[videogames_sales_df.columns[0]] == 'Pos' ) ]  ## We only need these rows to discard each page header
videogames_sales_df.columns = videogames_sales_df.iloc[0] ## First Row as header
videogames_sales_df = videogames_sales_df[1:] ##Discard First row (now header)
videogames_sales_df = videogames_sales_df[videogames_sales_df["Pos"].str.isnumeric()] ## We've already gotten the headers, so we don't need these rows

# %%
videogames_sales_df.head(10)
# Out:
# 2  Pos            Game                                           GameName  \
# 3    1  Boxart Missing  Star Wars: The Force Unleashed - Ultimate Sith...
# 4    2  Boxart Missing  Star Wars: The Force Unleashed - Ultimate Sith...
# 5    3  Boxart Missing  Star Wars: The Force Unleashed - Ultimate Sith...
# 6    4  Boxart Missing                                             Contra
# 7    5  Boxart Missing                                             Contra
# 8    6  Boxart Missing                                             Contra
# 9    7  Boxart Missing                                             Contra
# 10   8  Boxart Missing                                             Contra
# 11   9  Boxart Missing                                            Pac-Man
# 12  10  Boxart Missing                                            Pac-Man
#
# 2  Console Publisher  Developer VGChartz Score Critic Score User Score  \
# 3      PS3   Unknown  LucasArts            N/A          N/A        N/A
# 4     X360   Unknown  LucasArts            N/A          N/A        N/A
# 5       PC   Unknown  LucasArts            N/A          N/A        N/A
# 6       PC   Unknown     Konami            N/A          N/A        N/A
# 7       NS   Unknown     Konami            N/A          N/A        N/A
# 8      MSX   Unknown     Konami            N/A          N/A        N/A
# 9      Mob   Unknown     Konami            N/A          N/A        N/A
# 10     C64   Unknown     Konami            N/A          N/A        N/A
# 11      PC   Unknown      Namco            N/A          N/A        N/A
# 12     MSX   Unknown      Namco            N/A          N/A        N/A
#
# 2  Total Shipped Total Sales NA Sales PAL Sales Japan Sales Other Sales  \
# 3            N/A         N/A      N/A       N/A         N/A         N/A
# 4            N/A         N/A      N/A       N/A         N/A         N/A
# 5            N/A         N/A      N/A       N/A         N/A         N/A
# 6            N/A         N/A      N/A       N/A         N/A         N/A
# 7            N/A         N/A      N/A       N/A         N/A         N/A
# 8            N/A         N/A      N/A       N/A         N/A         N/A
# 9            N/A         N/A      N/A       N/A         N/A         N/A
# 10           N/A         N/A      N/A       N/A         N/A         N/A
# 11           N/A         N/A      N/A       N/A         N/A         N/A
# 12           N/A         N/A      N/A       N/A         N/A         N/A
#
# 2  Release Date  Last Update
# 3           N/A  06th Jan 24
# 4           N/A  06th Jan 24
# 5           N/A  06th Jan 24
# 6           N/A  05th Jan 24
# 7           N/A  05th Jan 24
# 8           N/A  05th Jan 24
# 9           N/A  05th Jan 24
# 10          N/A  05th Jan 24
# 11          N/A  05th Jan 24
# 12          N/A  05th Jan 24

# %% [markdown]
# ### Filters and needed transformations

# %%
videogames_sales_df.columns
# Out:
# Index(['Pos', 'Game', 'GameName', 'Console', 'Publisher', 'Developer',
#        'VGChartz Score', 'Critic Score', 'User Score', 'Total Shipped',
#        'Total Sales', 'NA Sales', 'PAL Sales', 'Japan Sales', 'Other Sales',
#        'Release Date', 'Last Update'],
#       dtype='object', name=2)

# %%
videogames_sales_df.drop(columns= {"Game", "Pos"}, inplace=True) ##To discard each page "Boxart Missing" message, and position in the results
videogames_sales_df= videogames_sales_df.replace('N/A', pd.NA)

# %%
videogames_sales_df.head(10)
# Out:
# 2                                            GameName Console Publisher  \
# 3   Star Wars: The Force Unleashed - Ultimate Sith...     PS3   Unknown
# 4   Star Wars: The Force Unleashed - Ultimate Sith...    X360   Unknown
# 5   Star Wars: The Force Unleashed - Ultimate Sith...      PC   Unknown
# 6                                              Contra      PC   Unknown
# 7                                              Contra      NS   Unknown
# 8                                              Contra     MSX   Unknown
# 9                                              Contra     Mob   Unknown
# 10                                             Contra     C64   Unknown
# 11                                            Pac-Man      PC   Unknown
# 12                                            Pac-Man     MSX   Unknown
#
# 2   Developer VGChartz Score Critic Score User Score Total Shipped  \
# 3   LucasArts           <NA>         <NA>       <NA>          <NA>
# 4   LucasArts           <NA>         <NA>       <NA>          <NA>
# 5   LucasArts           <NA>         <NA>       <NA>          <NA>
# 6      Konami           <NA>         <NA>       <NA>          <NA>
# 7      Konami           <NA>         <NA>       <NA>          <NA>
# 8      Konami           <NA>         <NA>       <NA>          <NA>
# 9      Konami           <NA>         <NA>       <NA>          <NA>
# 10     Konami           <NA>         <NA>       <NA>          <NA>
# 11      Namco           <NA>         <NA>       <NA>          <NA>
# 12      Namco           <NA>         <NA>       <NA>          <NA>
#
# 2  Total Sales NA Sales PAL Sales Japan Sales Other Sales Release Date  \
# 3         <NA>     <NA>      <NA>        <NA>        <NA>         <NA>
# 4         <NA>     <NA>      <NA>        <NA>        <NA>         <NA>
# 5         <NA>     <NA>      <NA>        <NA>        <NA>         <NA>
# 6         <NA>     <NA>      <NA>        <NA>        <NA>         <NA>
# 7         <NA>     <NA>      <NA>        <NA>        <NA>         <NA>
# 8         <NA>     <NA>      <NA>        <NA>        <NA>         <NA>
# 9         <NA>     <NA>      <NA>        <NA>        <NA>         <NA>
# 10        <NA>     <NA>      <NA>        <NA>        <NA>         <NA>
# 11        <NA>     <NA>      <NA>        <NA>        <NA>         <NA>
# 12        <NA>     <NA>      <NA>        <NA>        <NA>         <NA>
#
# 2   Last Update
# 3   06th Jan 24
# 4   06th Jan 24
# 5   06th Jan 24
# 6   05th Jan 24
# 7   05th Jan 24
# 8   05th Jan 24
# 9   05th Jan 24
# 10  05th Jan 24
# 11  05th Jan 24
# 12  05th Jan 24

# %% [markdown]
# ### Date columns Transformations

# %%
videogames_sales_df["Release Date"] = videogames_sales_df["Release Date"].apply(text_to_date)
videogames_sales_df["Last Update"] = videogames_sales_df["Last Update"].apply(text_to_date)
videogames_sales_df[["Release Date", "Last Update"]] = videogames_sales_df[["Release Date", "Last Update"]].apply(pd.to_datetime, errors='coerce')

# %% [markdown]
# ### Numeric columns Transformations

# %%
videogames_sales_df[['VGChartz Score', 'Critic Score', 'User Score']] = videogames_sales_df[['VGChartz Score', 'Critic Score', 'User Score']].\
                                                          apply(pd.to_numeric, errors='coerce', downcast='float')

# %%
videogames_sales_df[['Total Shipped', 'Total Sales', 'NA Sales', 'PAL Sales', 'Japan Sales', 'Other Sales']] = \
videogames_sales_df[['Total Shipped', 'Total Sales', 'NA Sales', 'PAL Sales', 'Japan Sales', 'Other Sales']].apply(lambda x : x.str.replace('m', '')).\
                                                                                            apply(pd.to_numeric, errors='coerce', downcast='float').\
                                                                                            apply(lambda x : x * 1000000.0)

# %%
videogames_sales_df.sample(10)
# Out:
# 2                                 GameName Console  \
# 32874                             Futurama     PS2
# 42716                 Mistborn: Birthright     PS3
# 50483                          Road Runner     NES
# 58350                  The Incredible Hulk      MS
# 29956         E.O.S. - Exhibition of Speed      DC
# 37220                               Jak II     PS2
# 36661                Impossible Mission-II     NES
# 29707                         Duke Assault      PC
# 19344  Alex Ferguson's Player Manager 2003      PC
# 24902                     Chaos Chronicles      PC
#
# 2                        Publisher                          Developer  \
# 32874                     VU Games  Unique Development Studios Sweden
# 42716                 Little Orbit                            Unknown
# 50483                       Tengen                             Tengen
# 58350                    U.S. Gold        Probe Entertainment Limited
# 29956                        Titus                           Player 1
# 37220  Sony Computer Entertainment                        Naughty Dog
# 36661                          SEI                          Novatrade
# 29707                      Unknown                        WizardWorks
# 19344                      Ubisoft                      Anco Software
# 24902            bitComposer Games                            Unknown
#
# 2      VGChartz Score  Critic Score  User Score  Total Shipped  Total Sales  \
# 32874             NaN           NaN         NaN            NaN      70000.0
# 42716             NaN           NaN         NaN            NaN          NaN
# 50483             NaN           NaN         NaN            NaN          NaN
# 58350             NaN           NaN         NaN            NaN          NaN
# 29956             NaN           NaN         NaN            NaN          NaN
# 37220             NaN           NaN         NaN      1600000.0          NaN
# 36661             NaN           NaN         NaN            NaN          NaN
# 29707             NaN           NaN         NaN            NaN          NaN
# 19344             NaN           NaN         NaN            NaN          NaN
# 24902             NaN           NaN         NaN            NaN          NaN
#
# 2      NA Sales  PAL Sales  Japan Sales  Other Sales Release Date Last Update
# 32874   40000.0    30000.0          NaN      10000.0   2003-08-14         NaT
# 42716       NaN        NaN          NaN          NaN   2020-12-31         NaT
# 50483       NaN        NaN          NaN          NaN   1989-01-01         NaT
# 58350       NaN        NaN          NaN          NaN   1994-01-01         NaT
# 29956       NaN        NaN          NaN          NaN   2001-08-21         NaT
# 37220       NaN        NaN          NaN          NaN   2003-10-14         NaT
# 36661       NaN        NaN          NaN          NaN   1990-01-01         NaT
# 29707       NaN        NaN          NaN          NaN          NaT         NaT
# 19344       NaN        NaN          NaN          NaN   2003-01-01         NaT
# 24902       NaN        NaN          NaN          NaN   2013-04-01         NaT

# %% [markdown]
# ### String Columns Transformations

# %%
videogames_sales_df[['GameName', 'Console', 'Publisher', 'Developer']] = videogames_sales_df[['GameName', 'Console', 'Publisher', 'Developer']].\
                                                        apply(lambda x : x.str.upper().str.strip()).\
                                                        replace('UNKNOWN', pd.NA)

# %% [markdown]
# ### Columns names cleaning

# %%
for col in videogames_sales_df.columns:
    print(col.strip().replace(' ', '_'))
    videogames_sales_df.rename(columns={col : col.strip().replace(' ', '_')}, inplace=True)
# Out:
# GameName
# Console
# Publisher
# Developer
# VGChartz_Score
# Critic_Score
# User_Score
# Total_Shipped
# Total_Sales
# NA_Sales
# PAL_Sales
# Japan_Sales
# Other_Sales
# Release_Date
# Last_Update

# %% [markdown]
# ### Final  Results show

# %%
videogames_sales_df.sample(20)
# Out:
# 2                                               GameName Console  \
# 56627                                          SURF'S UP    X360
# 52417                                         SHARK TALE     GBA
# 37218               JAK AND DAXTER: THE PRECURSOR LEGACY     PS2
# 18427                                      5 SPOTS PARTY      WW
# 31090                         FAIRY TAIL: PORTABLE GUILD     PSP
# 52814                                              SHOGI     PSN
# 21147                                          BABY PALS      DS
# 47143                                           PETZ VET     GBA
# 30174                            EIJUKUGO TARGET 1000 DS      DS
# 56817                                          SYNDICATE      PC
# 38339  KATEKYOO HITMAN REBORN!! LET'S ANSATSU!? NERAW...     PS2
# 57505                                 TENNIS NO OJI-SAMA      PS
# 56107       SUPER CHINESE WORLD 2: UCHUU ICHIBUTO DAIKAI    SNES
# 14949                         RIVER CITY: RIVAL SHOWDOWN     3DS
# 25929                   COMMANDER KEEN: MAROONED ON MARS      PC
# 56100                           SUPER CHALLENGE FOOTBALL    2600
# 23328                                            BOWLING      PS
# 54913                               SPOT: THE VIDEO GAME      GB
# 8632                   AMAZING ADVENTURES: THE LOST TOMB      PC
# 25047                  CHESTER CHEETAH: TOO COOL TO FOOL     GEN
#
# 2                        Publisher                            Developer  \
# 56627                      UBISOFT                     UBISOFT MONTREAL
# 52417                   ACTIVISION                    VICARIOUS VISIONS
# 37218  SONY COMPUTER ENTERTAINMENT                          NAUGHTY DOG
# 18427              COSMONAUT GAMES                      COSMONAUT GAMES
# 31090                       KONAMI                               KONAMI
# 52814  SONY COMPUTER ENTERTAINMENT  SONY COMPUTER ENTERTAINMENT AMERICA
# 21147          CRAVE ENTERTAINMENT                           BRAIN TOYS
# 47143                      UBISOFT                              UBISOFT
# 30174                 IE INSTITUTE                         IE INSTITUTE
# 56817                         <NA>                                 <NA>
# 38339        MARVELOUS INTERACTIVE                MARVELOUS INTERACTIVE
# 57505                       KONAMI                               KONAMI
# 56107                CULTURE BRAIN                        CULTURE BRAIN
# 14949                      NATSUME                     ARC SYSTEM WORKS
# 25929                       APOGEE                          ID SOFTWARE
# 56100           MATTEL INTERACTIVE                               MATTEL
# 23328                       AGETEC                              TAMSOFT
# 54913           VIRGIN INTERACTIVE                   SOFTWARE CREATIONS
# 8632                  POPCAP GAMES                        SPINTOP GAMES
# 25047               KANEKO CO. LTD                               KANEKO
#
# 2      VGChartz_Score  Critic_Score  User_Score  Total_Shipped  Total_Sales  \
# 56627             NaN           6.2         NaN            NaN     100000.0
# 52417             NaN           NaN         NaN            NaN     680000.0
# 37218             NaN           9.0         8.9            NaN    3640000.0
# 18427             NaN           NaN         NaN            NaN          NaN
# 31090             NaN           NaN         NaN            NaN     110000.0
# 52814             NaN           NaN         NaN            NaN          NaN
# 21147             NaN           NaN         NaN            NaN     280000.0
# 47143             NaN           NaN         NaN            NaN          NaN
# 30174             NaN           NaN         NaN            NaN          NaN
# 56817             NaN           NaN         NaN            NaN          NaN
# 38339             NaN           NaN         NaN            NaN      20000.0
# 57505             NaN           NaN         NaN            NaN          NaN
# 56107             NaN           NaN         NaN            NaN          NaN
# 14949             NaN           NaN         NaN            NaN          NaN
# 25929             NaN           NaN         NaN            NaN          NaN
# 56100             NaN           NaN         NaN            NaN          NaN
# 23328             NaN           2.3         NaN            NaN          NaN
# 54913             NaN           NaN         NaN            NaN          NaN
# 8632              NaN           NaN         NaN            NaN          0.0
# 25047             NaN           NaN         NaN            NaN          NaN
#
# 2          NA_Sales  PAL_Sales  Japan_Sales  Other_Sales Release_Date  \
# 56627  9.000000e+04        0.0          NaN      10000.0   2007-05-30
# 52417  4.900000e+05   180000.0          NaN      10000.0   2004-09-27
# 37218  2.080000e+06  1090000.0     150000.0     330000.0   2001-12-04
# 18427           NaN        NaN          NaN          NaN   2009-07-20
# 31090           NaN        NaN     110000.0          NaN   2010-06-03
# 52814           NaN        NaN          NaN          NaN   2010-04-22
# 21147  2.600000e+05    10000.0          NaN      20000.0   2007-11-19
# 47143           NaN        NaN          NaN          NaN   2007-03-26
# 30174           NaN        NaN          NaN          NaN   2007-08-09
# 56817           NaN        NaN          NaN          NaN          NaT
# 38339           NaN        NaN      20000.0          NaN   2007-10-25
# 57505           NaN        NaN          NaN          NaN   2002-02-28
# 56107           NaN        NaN          NaN          NaN   1993-10-29
# 14949           NaN        NaN          NaN          NaN   2017-11-21
# 25929           NaN        NaN          NaN          NaN   1990-12-14
# 56100           NaN        NaN          NaN          NaN   1982-01-01
# 23328           NaN        NaN          NaN          NaN   2001-05-14
# 54913           NaN        NaN          NaN          NaN   1991-09-01
# 8632            NaN        0.0          NaN          0.0   2007-11-05
# 25047           NaN        NaN          NaN          NaN   1992-01-01
#
# 2     Last_Update
# 56627         NaT
# 52417         NaT
# 37218         NaT
# 18427         NaT
# 31090         NaT
# 52814         NaT
# 21147         NaT
# 47143         NaT
# 30174         NaT
# 56817         NaT
# 38339         NaT
# 57505         NaT
# 56107         NaT
# 14949  2018-04-24
# 25929         NaT
# 56100         NaT
# 23328         NaT
# 54913         NaT
# 8632   2019-05-03
# 25047         NaT

# %%
videogames_sales_df_count = len(videogames_sales_df.index)
print("Total Count:", videogames_sales_df_count) # Count
if videogames_sales_df_count != results:
    raise ValueError(f"{results} games found in webpage, {videogames_sales_df_count} games scrapped. Difference: {results - videogames_sales_df_count}")
print("Max Updated Date:", videogames_sales_df["Last_Update"].max())
print("Max VGZ Score (it shouldn't be > 10)", videogames_sales_df["VGChartz_Score"].max())
print("Max Shipped units:", videogames_sales_df["Total_Shipped"].max())
print(videogames_sales_df.dtypes)
# Out:
# Total Count: 63916
# Max Updated Date: 2024-01-06 00:00:00
# Max VGZ Score (it shouldn't be > 10) 10.0
# Max Shipped units: 520000000.0
# 2
# GameName                  object
# Console                   object
# Publisher                 object
# Developer                 object
# VGChartz_Score           float32
# Critic_Score             float32
# User_Score               float32
# Total_Shipped            float32
# Total_Sales              float32
# NA_Sales                 float32
# PAL_Sales                float32
# Japan_Sales              float32
# Other_Sales              float32
# Release_Date      datetime64[ns]
# Last_Update       datetime64[ns]
# dtype: object

# %% [markdown]
# ### Saving Individual dimensions

# %%
dim_videogames_df = videogames_sales_df.rename(columns={"GameName" : 'Game_Name'})["Game_Name"].drop_duplicates()
dim_videogames_df_count = len(dim_videogames_df.index)

dim_console_df = videogames_sales_df.rename(columns={"Console": "Console_Abbreviation"})["Console_Abbreviation"].drop_duplicates()
dim_console_df_count = len(dim_console_df.index)

dim_publisher_df = videogames_sales_df[videogames_sales_df["Publisher"].notnull()]["Publisher"].drop_duplicates()
dim_publisher_df_count = len(dim_publisher_df.index)

dim_developer_df = videogames_sales_df[videogames_sales_df["Developer"].notnull()]["Developer"].drop_duplicates()
dim_developer_df_count = len(dim_developer_df.index)

# %% [markdown]
# ## Saving Final results directly to our database

# %% [markdown]
# ### We are using our SRC schema, which will save raw data before getting dimensions ids

# %% [markdown]
# #### Defining our connection string, shared by every table in the process

# %%
table_schema = 'SRC' ## Raw Data before replacing descriptions by ids
user_name = 'XXXXX' ## We won't save credentials on github! 
password =  'XXXXX' ## We won't save credentials on github!
dw_server = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'
db_name = 'VideoGames_Sales'

connection_string = (
    f'mssql+pyodbc://{user_name}:{password}@{dw_server}/'
    f'{db_name}?driver=ODBC+Driver+17+for+SQL+Server'
)

table_names = ['Fact_VideoGames_Sales', 'Dim_VideoGames', 'Dim_Console', 'Dim_Publisher', 'Dim_Developer']

# %% [markdown]
# ### Loading every table on db

# %%
# Connecting with SQL Server
engine = create_engine(url=connection_string, fast_executemany=True)

for table_name in table_names:

    try:
        start_time = time.time()

        ## Before inserting new records, we must truncate the intermediate table
        ## To avoid duplicated data
        with engine.connect() as conn:
            conn.execute(text(f"TRUNCATE TABLE {table_schema}.{table_name}"))
            conn.commit() ## We must commit our changes, otherwise they won't have effect
        print(f"{table_name} Successfully truncated! :D")

        ## Inserting new data
        if table_name == 'Fact_VideoGames_Sales':
            videogames_sales_df.to_sql(name=table_name,schema=table_schema, con=engine, index=False, if_exists='append')
            df_count = videogames_sales_df_count
            print(f"Source File rows: {videogames_sales_df_count}")
        elif table_name == 'Dim_VideoGames':
            dim_videogames_df.to_sql(name=table_name,schema=table_schema, con=engine, index=False, if_exists='append')
            df_count = dim_videogames_df_count
            print(f"Source File rows: {dim_videogames_df_count}")
        elif table_name == 'Dim_Console':
            dim_console_df.to_sql(name=table_name,schema=table_schema, con=engine, index=False, if_exists='append')
            df_count = dim_console_df_count
            print(f"Source File rows: {dim_console_df_count}")
        elif table_name == 'Dim_Publisher':
            dim_publisher_df.to_sql(name=table_name,schema=table_schema, con=engine, index=False, if_exists='append')
            df_count = dim_publisher_df_count
            print(f"Source File rows: {dim_publisher_df_count}")
        elif table_name == 'Dim_Developer':
            dim_developer_df.to_sql(name=table_name,schema=table_schema, con=engine, index=False, if_exists='append')
            df_count = dim_developer_df_count
            print(f"Source File rows: {dim_developer_df_count}")

        ## Cheking and comparing inserted rows
        with engine.connect() as conn:
            rows_affected = conn.execute(text(f"select count(1) from {table_schema}.{table_name}")).scalar()

        ### Printing and comparing row numbers
        print(f"Inserted rows: {rows_affected}")

        if (df_count != rows_affected):
            raise ValueError(f"Error on {table_name}! There is a difference of {df_count - rows_affected} between source and destination")
        
        end_time = time.time()
        elapsed_time = (end_time - start_time) / 60 ##Minutes
        
        print(f"{table_name} DB Insertion Finished in {elapsed_time} minutes ! :D")
        print("#############")
    except Exception as e:
        ## Properly closing connections
        engine.dispose()
        raise ValueError(f"Job Failed with the following message! :( : {str(e)}")

## Properly closing connections
engine.dispose()
print("Finished!")
# Out:
# Fact_VideoGames_Sales Successfully truncated! :D
# Source File rows: 63916
# Inserted rows: 63916
# Fact_VideoGames_Sales DB Insertion Finished in 0.06008257865905762 minutes ! :D
# #############
# Dim_VideoGames Successfully truncated! :D
# Source File rows: 41052
# Inserted rows: 41052
# Dim_VideoGames DB Insertion Finished in 0.008723243077596029 minutes ! :D
# #############
# Dim_Console Successfully truncated! :D
# Source File rows: 81
# Inserted rows: 81
# Dim_Console DB Insertion Finished in 0.0001665194829305013 minutes ! :D
# #############
# Dim_Publisher Successfully truncated! :D
# Source File rows: 3381
# Inserted rows: 3381
# Dim_Publisher DB Insertion Finished in 0.0008462786674499512 minutes ! :D
# #############
# Dim_Developer Successfully truncated! :D
# Source File rows: 8846
# Inserted rows: 8846
# Dim_Developer DB Insertion Finished in 0.0018828352292378744 minutes ! :D
# #############
# Finished!
